# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pprint import pprint

# %%
with open("apikey.txt") as k:
    key = k.read()

# %%
import os
os.getcwd()
# Out:
# '/home/benjamin/projects/pointcontrol'

# %%
from collect_data import get_tournament_events

# %%
from collect_data import get_tournaments

# %%
data = get_tournaments(key)
data
# Out:
# {'filters': {'_sort': 'start_date_desc'},
#  'total_matched': 36649,
#  'page': 1,
#  'per_page': 100,
#  'tournaments': [{'id': 45344,
#    'name': 'test',
#    'start_date': '2022-09-29',
#    'end_date': '',
#    'comments': '',
#    'prereg_open': '2019-10-01',
#    'prereg_close': '2022-09-28',
#    'authority': 'BFA',
#    'is_fee_required': False,
#    'is_roc': False,
#    'is_baycup': False,
#    'is_visible': False,
#    'is_cancelled': False,
#    'is_accepting_fees_online': True,
#    'fee': 10,
#    'fee_currency': 'USD',
#    'more_info': '',
#    'venue': {'name': 'Here',
#     'address': '58 B Bramfield Rd',
#     'city': 'London',
#     'state': 'UK',
#     'zip': 'SW11 6RB',
#     'country': 'GBR',
#     'timezone': None,
#     'latitude': 51.4553321,
#     'longitude': -0.1655041,
#     'geocode_precision': 'street'},
#    'division': {'id': 86, 'name': 'UK(Great Britain)', 'abbrev': 'GBR'},
#    'events': [{'id': 179426,
#      'tournament_id': 45344,
# ...
